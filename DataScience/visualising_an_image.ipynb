# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimage
# %matplotlib inline  
# Show image in jupyter notebook

# %%
image_arr = mpimage.imread('image.jpg')

# %%
image_arr
# Out:
# array([[[18, 31, 37],
#         [18, 31, 37],
#         [18, 31, 37],
#         ...,
#         [24, 39, 44],
#         [24, 39, 44],
#         [23, 38, 43]],
#
#        [[18, 31, 37],
#         [18, 31, 37],
#         [18, 31, 37],
#         ...,
#         [26, 41, 46],
#         [25, 40, 45],
#         [24, 39, 44]],
#
#        [[18, 31, 37],
#         [18, 31, 37],
#         [18, 31, 37],
#         ...,
#         [25, 40, 45],
#         [24, 39, 44],
#         [22, 37, 42]],
#
#        ...,
#
#        [[18, 29, 35],
#         [18, 29, 35],
#         [18, 29, 35],
#         ...,
#         [31, 32, 36],
#         [31, 32, 36],
#         [30, 31, 35]],
#
#        [[18, 29, 35],
#         [18, 29, 35],
#         [18, 29, 35],
#         ...,
#         [32, 31, 36],
#         [31, 32, 36],
#         [29, 30, 34]],
#
#        [[18, 29, 35],
#         [18, 29, 35],
#         [18, 29, 35],
#         ...,
#         [33, 32, 37],
#         [31, 32, 36],
#         [29, 30, 34]]], dtype=uint8)

# %%
image_arr.dtype
# Out:
# dtype('uint8')

# %%
fig = plt.figure(figsize=(18, 18))   #For size of image
img = plt.imshow(image_arr)

# %%
image_arr.shape
# Out:
# (6240, 4160, 3)

# %%
image_arr.ndim
# Out:
# 3

# %%
fig = plt.figure(figsize=(18, 18))   #For size of image
img = plt.imshow(image_arr[:, :, 0])
